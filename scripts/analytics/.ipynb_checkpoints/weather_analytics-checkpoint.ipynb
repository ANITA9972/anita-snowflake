# %%
# snowpark_analysis.ipynb
"""
# Weather Data Analytics Notebook with Snowpark

This notebook performs analysis on the transformed weather data in Snowflake using Snowpark.
"""

# Install required packages
# !pip install snowflake-snowpark-python[pandas] plotly matplotlib seaborn

# Import libraries
from snowflake.snowpark import Session
from snowflake.snowpark.functions import col, avg, min, max, count, stddev, hour, dayofweek, month
from snowflake.snowpark.types import DecimalType, StringType, IntegerType
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# Requirement already satisfied: plotly in c:\users\anita\documents\data_projects\.venv\lib\site-packages (5.19.0)
# Requirement already satisfied: matplotlib in c:\users\anita\documents\data_projects\.venv\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\anita\documents\data_projects\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: snowflake-snowpark-python[pandas] in c:\users\anita\documents\data_projects\.venv\lib\site-packages (1.43.0)
# Requirement already satisfied: setuptools>=40.6.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-snowpark-python[pandas]) (80.9.0)
# Requirement already satisfied: wheel in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-snowpark-python[pandas]) (0.45.1)
# Requirement already satisfied: snowflake-connector-python<5.0.0,>=3.17.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-snowpark-python[pandas]) (4.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-snowpark-python[pandas]) (4.15.0)
# Requirement already satisfied: pyyaml in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-snowpark-python[pandas]) (6.0.3)
# Requirement already satisfied: cloudpickle!=2.1.0,!=2.2.0,<=3.1.1,>=1.6.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-snowpark-python[pandas]) (3.1.1)
# Requirement already satisfied: protobuf<6.32,>=3.20 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-snowpark-python[pandas]) (4.25.8)
# Requirement already satisfied: python-dateutil in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-snowpark-python[pandas]) (2.9.0.post0)
# Requirement already satisfied: tzlocal in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-snowpark-python[pandas]) (5.3.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from plotly) (8.5.0)
# Requirement already satisfied: packaging in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from plotly) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: pillow>=8 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: pandas>=1.2 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from python-dateutil->snowflake-snowpark-python[pandas]) (1.17.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (1.5.1)
# Requirement already satisfied: cryptography>=3.1.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (46.0.3)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=22.0.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (25.3.0)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (2.10.1)
# Requirement already satisfied: requests<3.0.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (2025.11.12)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (3.20.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (4.5.1)
# Requirement already satisfied: tomlkit in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (0.13.3)
# Requirement already satisfied: boto3>=1.24 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (1.42.8)
# Requirement already satisfied: botocore>=1.24 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (1.42.8)
# Requirement already satisfied: pyarrow in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from snowflake-connector-python[pandas]<5.0.0,>=3.17.0; extra == "pandas"->snowflake-snowpark-python[pandas]) (22.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from boto3>=1.24->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from boto3>=1.24->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (0.16.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from botocore>=1.24->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (2.6.2)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from cryptography>=3.1.0->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\anita\documents\data_projects\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=3.1.0->snowflake-connector-python<5.0.0,>=3.17.0->snowflake-snowpark-python[pandas]) (2.23)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# True

# %%
# ====================
# 1. CONNECT TO SNOWFLAKE
# ====================

def create_snowpark_session():
    """Create and return Snowpark session"""
    connection_params = {
        "account": os.getenv('SNOWFLAKE_ACCOUNT'),
        "user": os.getenv('SNOWFLAKE_USER'),
        "password": os.getenv('SNOWFLAKE_PASSWORD'),
        "warehouse": os.getenv('SNOWFLAKE_WAREHOUSE'),
        "database": os.getenv('SNOWFLAKE_DATABASE'),
        "schema": "SILVER",
        "role": "ACCOUNTADMIN"
    }
    
    print("🔗 Connecting to Snowflake...")
    session = Session.builder.configs(connection_params).create()
    print("✅ Connected successfully!")
    return session

# Create session
session = create_snowpark_session()
# Out:
# 🔗 Connecting to Snowflake...
# ✅ Connected successfully!

# %%
# ====================
# 2. LOAD AND EXPLORE DATA
# ====================

print("\n" + "="*60)
print("2. LOADING AND EXPLORING WEATHER DATA")
print("="*60)

# Load current weather data
print("\n📊 Loading CURRENT_WEATHER_CLEANED table...")
weather_df = session.table("CURRENT_WEATHER_CLEANED")

# Show basic information
print(f"\n📈 Total records: {weather_df.count():,}")
print(f"📅 Date range: {weather_df.select(col('DATE')).distinct().count()} days")

# Show schema
print("\n🔍 Table schema:")
weather_df.printSchema()

# Show sample data
print("\n👀 Sample data (10 rows):")
weather_df.limit(10).show()
# Out:
# ============================================================
# 2. LOADING AND EXPLORING WEATHER DATA
# ============================================================
#
# 📊 Loading CURRENT_WEATHER_CLEANED table...
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# Cell In[3], line 14
#      11 weather_df = session.table("CURRENT_WEATHER_CLEANED")
#      13 # Show basic information
# ---> 14 print(f"\n📈 Total records: {weather_df.count():,}")
#      15 print(f"📅 Date range: {weather_df.select(col('DATE')).distinct().count()} days")
#      17 # Show schema
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\utils.py:1148, in publicapi.<locals>.call_wrapper(*args, **kwargs)
#    1144 kwargs["_emit_ast"] = is_ast_enabled()
#    1146 # TODO: Could modify internal docstring to display that users should not modify the _emit_ast parameter.
# -> 1148 return func(*args, **kwargs)
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\dataframe.py:4622, in DataFrame.count(self, statement_params, block, _emit_ast)
#    4620 df = self.agg(("*", "count"), _emit_ast=False)
#    4621 adjust_api_subcalls(df, "DataFrame.count", len_subcalls=1)
# -> 4622 result = df._internal_collect_with_tag(
#    4623     statement_params=statement_params,
#    4624     block=block,
#    4625     data_type=_AsyncResultType.COUNT,
#    4626     **kwargs,
#    4627 )
#    4628 return result[0][0] if block else result
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\telemetry.py:295, in df_collect_api_telemetry.<locals>.wrap(*args, **kwargs)
#     293 try:
#     294     with ResourceUsageCollector() as resource_usage_collector:
# --> 295         result = func(*args, **kwargs)
#     296     resource_usage = resource_usage_collector.get_resource_usage()
#     297 finally:
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\dataframe.py:847, in DataFrame._internal_collect_with_tag_no_telemetry(self, statement_params, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     831 def _internal_collect_with_tag_no_telemetry(
#     832     self,
#     833     *,
#    (...)    842     # we should always call this method instead of collect(), to make sure the
#     843     # query tag is set properly.
#     844     statement_params = track_data_source_statement_params(
#     845         self, statement_params or self._statement_params
#     846     )
# --> 847     return self._session._conn.execute(
#     848         self._plan,
#     849         block=block,
#     850         data_type=data_type,
#     851         _statement_params=create_or_update_statement_params_with_query_tag(
#     852             statement_params or self._statement_params,
#     853             self._session.query_tag,
#     854             SKIP_LEVELS_THREE,
#     855             collect_stacktrace=self._session.conf.get(
#     856                 "collect_stacktrace_in_query_tag"
#     857             ),
#     858         ),
#     859         log_on_exception=log_on_exception,
#     860         case_sensitive=case_sensitive,
#     861         **kwargs,
#     862     )
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\server_connection.py:648, in ServerConnection.execute(self, plan, to_pandas, to_iter, to_arrow, block, data_type, log_on_exception, case_sensitive, **kwargs)
#     638 if (
#     639     is_in_stored_procedure()
#     640     and not block
#    (...)    643     )
#     644 ):  # pragma: no cover
#     645     raise NotImplementedError(
#     646         "Async query is not supported in stored procedure yet"
#     647     )
# --> 648 result_set, result_meta = self.get_result_set(
#     649     plan,
#     650     to_pandas,
#     651     to_iter,
#     652     **kwargs,
#     653     block=block,
#     654     data_type=data_type,
#     655     log_on_exception=log_on_exception,
#     656     case_sensitive=case_sensitive,
#     657     to_arrow=to_arrow,
#     658 )
#     659 if not block:
#     660     return result_set
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:426, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     421                 raise ne.with_traceback(tb) from None
#     423 ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     424     e, debug_context=debug_context
#     425 )
# --> 426 raise ne.with_traceback(tb) from None
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\analyzer\snowflake_plan.py:179, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     173 from snowflake.snowpark.context import (
#     174     _enable_dataframe_trace_on_error,
#     175     _enable_trace_sql_errors_to_dataframe,
#     176 )
#     178 try:
# --> 179     return func(*args, **kwargs)
#     180 except snowflake.connector.errors.ProgrammingError as e:
#     181     from snowflake.snowpark._internal.analyzer.select_statement import (
#     182         Selectable,
#     183     )
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\server_connection.py:770, in ServerConnection.get_result_set(self, plan, to_pandas, to_iter, block, data_type, log_on_exception, case_sensitive, ignore_results, to_arrow, **kwargs)
#     768     kwargs[DATAFRAME_AST_PARAMETER] = dataframe_ast
#     769 is_final_query = i == len(main_queries) - 1
# --> 770 result = self.run_query(
#     771     final_query,
#     772     to_pandas,
#     773     to_iter and is_final_query,
#     774     is_ddl_on_temp_object=query.is_ddl_on_temp_object,
#     775     block=not is_last,
#     776     data_type=data_type,
#     777     async_job_plan=plan,
#     778     log_on_exception=log_on_exception,
#     779     case_sensitive=case_sensitive,
#     780     params=query.params,
#     781     ignore_results=ignore_results,
#     782     async_post_actions=post_actions,
#     783     to_arrow=to_arrow and is_final_query,
#     784     **kwargs,
#     785 )
#     786 placeholders[query.query_id_place_holder] = (
#     787     result["sfqid"] if not is_last else result.query_id
#     788 )
#     789 result_meta = get_new_description(self._cursor)
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\server_connection.py:137, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     133     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     134         ex.cause
#     135     )
#     136 except Exception as ex:
# --> 137     raise ex
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\server_connection.py:131, in ServerConnection._Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     129     raise SnowparkClientExceptionMessages.SERVER_SESSION_HAS_BEEN_CLOSED()
#     130 try:
# --> 131     return func(*args, **kwargs)
#     132 except ReauthenticationRequest as ex:
#     133     raise SnowparkClientExceptionMessages.SERVER_SESSION_EXPIRED(
#     134         ex.cause
#     135     )
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\server_connection.py:544, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, async_post_actions, to_arrow, **kwargs)
#     542         query_id_log = f" [queryID: {ex.sfqid}]" if hasattr(ex, "sfqid") else ""
#     543         logger.error(f"Failed to execute query{query_id_log} {query}\n{ex}")
# --> 544     raise ex
#     546 # fetch_pandas_all/batches() only works for SELECT statements
#     547 # We call fetchall() if fetch_pandas_all/batches() fails,
#     548 # because when the query plan has multiple queries, it will
#     549 # have non-select statements, and it shouldn't fail if the user
#     550 # calls to_pandas() to execute the query.
#     551 if block:
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\server_connection.py:529, in ServerConnection.run_query(self, query, to_pandas, to_iter, is_ddl_on_temp_object, block, data_type, async_job_plan, log_on_exception, case_sensitive, params, num_statements, ignore_results, async_post_actions, to_arrow, **kwargs)
#     527     cached_analyze_attributes.clear_cache()
#     528 if block:
# --> 529     results_cursor = self.execute_and_notify_query_listener(
#     530         query, params=params, **kwargs
#     531     )
#     532     logger.debug(f"Execute query [queryID: {results_cursor.sfqid}] {query}")
#     533 else:
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\server_connection.py:459, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     455     err_query = ex.query if isinstance(ex, Error) else query
#     456     self.notify_query_listeners(
#     457         QueryRecord(sfqid, err_query, False), is_error=True, **notify_kwargs
#     458     )
# --> 459     raise ex
#     461 notify_kwargs["requestId"] = str(results_cursor._request_id)
#     462 self.notify_query_listeners(
#     463     QueryRecord(results_cursor.sfqid, results_cursor.query), **notify_kwargs
#     464 )
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\snowpark\_internal\server_connection.py:450, in ServerConnection.execute_and_notify_query_listener(self, query, **kwargs)
#     448         notify_kwargs["dataframe_uuid"] = statement_params["_PLAN_UUID"]
#     449 try:
# --> 450     results_cursor = self._cursor.execute(query, **kwargs)
#     451 except Exception as ex:
#     452     notify_kwargs["requestId"] = None
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\connector\cursor.py:1121, in SnowflakeCursorBase.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements, _force_qmark_paramstyle, _dataframe_ast)
#    1117     is_integrity_error = (
#    1118         code == "100072"
#    1119     )  # NULL result in a non-nullable column
#    1120     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1121     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1122 return self
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\connector\errors.py:286, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     263 @staticmethod
#     264 def errorhandler_wrapper(
#     265     connection: SnowflakeConnection | None,
#    (...)    268     error_value: dict[str, Any],
#     269 ) -> None:
#     270     """Error handler wrapper that calls the errorhandler method.
#     271
#     272     Args:
#    (...)    283         exception to the first handler in that order.
#     284     """
# --> 286     handed_over = Error.hand_to_other_handler(
#     287         connection,
#     288         cursor,
#     289         error_class,
#     290         error_value,
#     291     )
#     292     if not handed_over:
#     293         raise Error.errorhandler_make_exception(
#     294             error_class,
#     295             error_value,
#     296         )
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\connector\errors.py:341, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     339 if cursor is not None:
#     340     cursor.messages.append((error_class, error_value))
# --> 341     cursor.errorhandler(connection, cursor, error_class, error_value)
#     342     return True
#     343 elif connection is not None:
#
# File ~\Documents\data_projects\.venv\Lib\site-packages\snowflake\connector\errors.py:217, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     215 errno = error_value.get("errno")
#     216 done_format_msg = error_value.get("done_format_msg")
# --> 217 raise error_class(
#     218     msg=error_value.get("msg"),
#     219     errno=None if errno is None else int(errno),
#     220     sqlstate=error_value.get("sqlstate"),
#     221     sfqid=error_value.get("sfqid"),
#     222     query=error_value.get("query"),
#     223     done_format_msg=(
#     224         None if done_format_msg is None else bool(done_format_msg)
#     225     ),
#     226     connection=connection,
#     227     cursor=cursor,
#     228 )
#
# SnowparkSQLException: (1304): 01c101b7-0205-b222-0004-52fe0002d11e: 002003 (42S02): SQL compilation error:
# Object 'CURRENT_WEATHER_CLEANED' does not exist or not authorized.

# %%
# ====================
# 3. DATA QUALITY CHECKS
# ====================

print("\n" + "="*60)
print("3. DATA QUALITY ANALYSIS")
print("="*60)

# Check for missing values
print("\n🔎 Checking for missing values:")
missing_data = weather_df.select([
    count("*").alias("total_rows"),
    count(col("TEMPERATURE")).alias("temp_not_null"),
    count(col("HUMIDITY")).alias("humidity_not_null"),
    count(col("WIND_SPEED")).alias("wind_not_null")
]).collect()[0]

print(f"Total rows: {missing_data['TOTAL_ROWS']}")
print(f"Temperature not null: {missing_data['TEMP_NOT_NULL']} ({(missing_data['TEMP_NOT_NULL']/missing_data['TOTAL_ROWS']*100):.1f}%)")
print(f"Humidity not null: {missing_data['HUMIDITY_NOT_NULL']} ({(missing_data['HUMIDITY_NOT_NULL']/missing_data['TOTAL_ROWS']*100):.1f}%)")
print(f"Wind speed not null: {missing_data['WIND_NOT_NULL']} ({(missing_data['WIND_NOT_NULL']/missing_data['TOTAL_ROWS']*100):.1f}%)")

# Data quality flags distribution
print("\n🚩 Data quality flags distribution:")
quality_flags = weather_df.group_by("DATA_QUALITY_FLAG").agg(
    count("*").alias("count")
).sort(col("count").desc()).to_pandas()

print(quality_flags.to_string(index=False))

# %%
# ====================
# 4. BASIC STATISTICS
# ====================

print("\n" + "="*60)
print("4. BASIC STATISTICAL ANALYSIS")
print("="*60)

# Calculate basic statistics
stats_df = weather_df.select([
    avg(col("TEMPERATURE")).alias("avg_temp"),
    min(col("TEMPERATURE")).alias("min_temp"),
    max(col("TEMPERATURE")).alias("max_temp"),
    stddev(col("TEMPERATURE")).alias("std_temp"),
    avg(col("HUMIDITY")).alias("avg_humidity"),
    avg(col("WIND_SPEED")).alias("avg_wind_speed"),
    avg(col("PRESSURE")).alias("avg_pressure"),
    avg(col("COMFORT_INDEX")).alias("avg_comfort")
]).collect()[0]

print("\n📊 Weather Statistics:")
print(f"🌡️  Temperature: {stats_df['AVG_TEMP']:.1f}°C (Min: {stats_df['MIN_TEMP']:.1f}°C, Max: {stats_df['MAX_TEMP']:.1f}°C)")
print(f"💧 Humidity: {stats_df['AVG_HUMIDITY']:.1f}%")
print(f"💨 Wind Speed: {stats_df['AVG_WIND_SPEED']:.1f} m/s")
print(f"📊 Pressure: {stats_df['AVG_PRESSURE']:.1f} hPa")
print(f"😊 Comfort Index: {stats_df['AVG_COMFORT']:.1f}/100")

# %%
# ====================
# 5. TEMPORAL ANALYSIS
# ====================

print("\n" + "="*60)
print("5. TEMPORAL PATTERNS ANALYSIS")
print("="*60)

# Hourly patterns
print("\n⏰ Analyzing hourly patterns...")
hourly_stats = weather_df.group_by("HOUR").agg(
    avg("TEMPERATURE").alias("avg_temp"),
    avg("HUMIDITY").alias("avg_humidity"),
    avg("WIND_SPEED").alias("avg_wind_speed"),
    count("*").alias("readings_count")
).sort("HOUR").to_pandas()

print("\nHourly Statistics (first 12 hours):")
print(hourly_stats.head(12).to_string(index=False))

# Daily patterns
print("\n📅 Analyzing daily patterns...")
daily_stats = weather_df.group_by("DAY_OF_WEEK").agg(
    avg("TEMPERATURE").alias("avg_temp"),
    avg("HUMIDITY").alias("avg_humidity"),
    count("*").alias("readings_count")
).sort("DAY_OF_WEEK").to_pandas()

print("\nDaily Statistics:")
print(daily_stats.to_string(index=False))

# %%
# ====================
# 6. GEOGRAPHICAL ANALYSIS
# ====================

print("\n" + "="*60)
print("6. GEOGRAPHICAL ANALYSIS")
print("="*60)

# Cities analysis
print("\n🏙️ Analyzing data by city...")
city_stats = weather_df.group_by(["CITY_NAME", "COUNTRY_CODE", "CLIMATE_ZONE", "HEMISPHERE"]).agg(
    count("*").alias("readings_count"),
    avg("TEMPERATURE").alias("avg_temp"),
    min("TEMPERATURE").alias("min_temp"),
    max("TEMPERATURE").alias("max_temp"),
    avg("HUMIDITY").alias("avg_humidity"),
    avg("COMFORT_INDEX").alias("avg_comfort")
).sort(col("avg_temp").desc()).limit(20).to_pandas()

print("\nTop 20 Cities by Average Temperature:")
print(city_stats.to_string(index=False))

# Climate zone analysis
print("\n🌍 Analyzing by climate zone...")
climate_stats = weather_df.group_by("CLIMATE_ZONE").agg(
    count("*").alias("readings_count"),
    avg("TEMPERATURE").alias("avg_temp"),
    avg("HUMIDITY").alias("avg_humidity"),
    avg("COMFORT_INDEX").alias("avg_comfort")
).sort(col("avg_temp").desc()).to_pandas()

print("\nClimate Zone Statistics:")
print(climate_stats.to_string(index=False))

# %%
# ====================
# 7. WEATHER CONDITIONS ANALYSIS
# ====================

print("\n" + "="*60)
print("7. WEATHER CONDITIONS ANALYSIS")
print("="*60)

# Weather conditions distribution
print("\n🌤️ Weather conditions distribution...")
weather_conditions = weather_df.group_by("WEATHER_MAIN").agg(
    count("*").alias("frequency"),
    avg("TEMPERATURE").alias("avg_temp"),
    avg("HUMIDITY").alias("avg_humidity"),
    avg("WIND_SPEED").alias("avg_wind_speed")
).sort(col("frequency").desc()).limit(10).to_pandas()

print("\nTop 10 Weather Conditions:")
print(weather_conditions.to_string(index=False))

# Comfort levels analysis
print("\n😊 Comfort levels distribution...")
comfort_stats = weather_df.group_by("COMFORT_LEVEL").agg(
    count("*").alias("frequency"),
    avg("TEMPERATURE").alias("avg_temp"),
    avg("HUMIDITY").alias("avg_humidity")
).sort(col("frequency").desc()).to_pandas()

print("\nComfort Levels:")
print(comfort_stats.to_string(index=False))

# %%
# ====================
# 8. ADVANCED ANALYSIS
# ====================

print("\n" + "="*60)
print("8. ADVANCED ANALYTICS")
print("="*60)

# Correlation analysis
print("\n📈 Analyzing correlations...")
correlation_sample = weather_df.select(
    "TEMPERATURE", "HUMIDITY", "WIND_SPEED", "PRESSURE", "COMFORT_INDEX"
).limit(1000).to_pandas()

correlation_matrix = correlation_sample.corr()
print("\nCorrelation Matrix:")
print(correlation_matrix.round(3))

# Temperature extremes
print("\n🔥❄️ Temperature extremes analysis...")
temp_extremes = weather_df.select(
    "CITY_NAME", "TEMPERATURE", "TIMESTAMP", "WEATHER_MAIN"
).filter(
    (col("TEMPERATURE") >= 30) | (col("TEMPERATURE") <= 0)
).sort(col("TEMPERATURE").desc()).limit(10).to_pandas()

print("\nTop 10 Temperature Extremes:")
print(temp_extremes.to_string(index=False))

# %%
# ====================
# 9. VISUALIZATIONS
# ====================

print("\n" + "="*60)
print("9. DATA VISUALIZATIONS")
print("="*60)

# Convert more data to pandas for visualization
print("\n📊 Preparing data for visualizations...")
viz_data = weather_df.select(
    "CITY_NAME", "TEMPERATURE", "HUMIDITY", "WIND_SPEED", 
    "CLIMATE_ZONE", "HEMISPHERE", "WEATHER_MAIN", "COMFORT_LEVEL",
    "SEASON", "TIMESTAMP", "HOUR", "DAY_OF_WEEK"
).limit(5000).to_pandas()

# 9.1 Temperature Distribution by City
print("\n📈 Plot 1: Temperature Distribution by City")
plt.figure(figsize=(12, 6))
top_cities = viz_data['CITY_NAME'].value_counts().index[:10]
filtered_data = viz_data[viz_data['CITY_NAME'].isin(top_cities)]

sns.boxplot(x='CITY_NAME', y='TEMPERATURE', data=filtered_data)
plt.title('Temperature Distribution by City', fontsize=14, fontweight='bold')
plt.xlabel('City')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# 9.2 Weather Conditions Pie Chart
print("\n🥧 Plot 2: Weather Conditions Distribution")
weather_counts = viz_data['WEATHER_MAIN'].value_counts().head(8)
plt.figure(figsize=(10, 8))
plt.pie(weather_counts.values, labels=weather_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Weather Conditions', fontsize=14, fontweight='bold')
plt.axis('equal')
plt.show()

# %%
# 9.3 Hourly Temperature Pattern
print("\n⏰ Plot 3: Hourly Temperature Pattern")
hourly_avg = viz_data.groupby('HOUR')['TEMPERATURE'].mean()
plt.figure(figsize=(12, 6))
plt.plot(hourly_avg.index, hourly_avg.values, marker='o', linewidth=2)
plt.title('Average Temperature by Hour of Day', fontsize=14, fontweight='bold')
plt.xlabel('Hour of Day')
plt.ylabel('Temperature (°C)')
plt.grid(True, alpha=0.3)
plt.xticks(range(0, 24, 2))
plt.tight_layout()
plt.show()

# %%
# 9.4 Correlation Heatmap
print("\n🔥 Plot 4: Correlation Heatmap")
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, 
            square=True, linewidths=1, cbar_kws={"shrink": 0.8})
plt.title('Correlation Matrix of Weather Variables', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# 9.5 Comfort Level by Climate Zone
print("\n😊 Plot 5: Comfort Level by Climate Zone")
comfort_by_climate = pd.crosstab(viz_data['CLIMATE_ZONE'], viz_data['COMFORT_LEVEL'], normalize='index')
comfort_by_climate.plot(kind='bar', stacked=True, figsize=(12, 6), colormap='viridis')
plt.title('Comfort Level Distribution by Climate Zone', fontsize=14, fontweight='bold')
plt.xlabel('Climate Zone')
plt.ylabel('Proportion')
plt.legend(title='Comfort Level', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# ====================
# 10. INSIGHTS & RECOMMENDATIONS
# ====================

print("\n" + "="*60)
print("10. KEY INSIGHTS & RECOMMENDATIONS")
print("="*60)

print("\n🔍 KEY INSIGHTS:")
print("1. 🌡️  Temperature Range: The data shows temperatures ranging from {:.1f}°C to {:.1f}°C"
      .format(stats_df['MIN_TEMP'], stats_df['MAX_TEMP']))
print("2. 🏙️  City Variations: {} has the highest average temperature while {} has the lowest"
      .format(city_stats.iloc[0]['CITY_NAME'], city_stats.iloc[-1]['CITY_NAME']))
print("3. ⏰ Daily Pattern: Temperatures typically peak around hour {}, reaching {:.1f}°C"
      .format(hourly_stats.loc[hourly_stats['AVG_TEMP'].idxmax()]['HOUR'], 
              hourly_stats['AVG_TEMP'].max()))
print("4. 🌍 Climate Impact: {} zones are {}°C warmer than {} zones on average"
      .format(climate_stats.iloc[0]['CLIMATE_ZONE'], 
              round(climate_stats.iloc[0]['AVG_TEMP'] - climate_stats.iloc[-1]['AVG_TEMP'], 1),
              climate_stats.iloc[-1]['CLIMATE_ZONE']))
print("5. 😊 Comfort Levels: {}% of readings are in 'Comfortable' or 'Very Comfortable' range"
      .format(round(comfort_stats[comfort_stats['COMFORT_LEVEL'].isin(['COMFORTABLE', 'VERY_COMFORTABLE'])]['FREQUENCY'].sum() / 
              comfort_stats['FREQUENCY'].sum() * 100, 1)))

print("\n💡 RECOMMENDATIONS:")
print("1. 📊 Data Quality: {}% of data has quality flags - consider data cleaning"
      .format(round((quality_flags[quality_flags['DATA_QUALITY_FLAG'] != 'VALID']['COUNT'].sum() / 
              quality_flags['COUNT'].sum()) * 100, 1)))
print("2. ⚡ Real-time Analysis: Consider implementing real-time alerts for extreme temperatures")
print("3. 🎯 Target Analysis: Focus on improving comfort index in {} zones"
      .format(climate_stats.loc[climate_stats['AVG_COMFORT'].idxmin()]['CLIMATE_ZONE']))
print("4. 📈 Forecasting: Implement time-series forecasting for temperature predictions")
print("5. 🔄 Automation: Schedule regular data updates and anomaly detection")
